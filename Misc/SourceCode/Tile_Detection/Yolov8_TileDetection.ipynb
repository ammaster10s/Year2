# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install ultralytics

# %%
import os

from ultralytics import YOLO

# %%
model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/gdrive/MyDrive/Prime/Tile_seg/For_tiles.yml', epochs=100, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:01<00:00, 5.44MB/s]
# Ultralytics YOLOv8.0.191 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/Prime/Tile_seg'

# %%
# Load a pretrained YOLOv8n model
model = YOLO('/content/runs/segment/train/weights/best.pt')

# %%
model.predict('/content/line_236664234853413.png', save=True, imgsz=320, conf=0.5) #ใส่ path ของรูป
# Out:
# image 1/1 /content/line_236664234853413.png: 320x320 1 Tile, 10.4ms
# Speed: 3.5ms preprocess, 10.4ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/segment/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'Tile'}
#  orig_img: array([[[ 72,  81,  84],
#          [ 72,  81,  84],
#          [ 77,  86,  89],
#          ...,
#          [112, 120, 119],
#          [113, 121, 120],
#          [112, 120, 119]],
#
#         [[ 72,  81,  84],
#          [ 69,  78,  81],
#          [ 72,  81,  84],
#          ...,
#          [108, 116, 115],
#          [110, 118, 117],
#          [111, 119, 118]],
#
#         [[ 73,  82,  85],
#          [ 70,  79,  82],
#          [ 72,  81,  84],
#          ...,
#          [106, 114, 113],
#          [108, 116, 115],
#          [108, 116, 115]],
#
#         ...,
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/Prime/Tile_seg'
